# %%
# !pip install simpy
# Out:
# Collecting simpy
#   Downloading simpy-4.1.1-py3-none-any.whl.metadata (6.1 kB)
# Downloading simpy-4.1.1-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.1

# %%
import simpy
import random
import numpy as np
import matplotlib.pyplot as plt

# Parametry symulacji
LAMBDA = 6  # średnia liczba pacjentów na godzinę (przychodzą zgodnie z procesem Poissona)
MU = 1 / 15  # średni czas wizyty wynosi 15 minut (rozkład wykładniczy)
SIM_TIME = 8 * 60  # symulacja 8 godzin (w minutach)
LEKARZE = 3  # liczba lekarzy (kanałów)

# Zmienne do śledzenia liczby pacjentów
total_patients = 0
waiting_times = []

# Zmienne do przechowywania danych dla wykresów
time_data = []
queue_data = []
in_service_data = []

# Funkcja przeliczająca czas minutowy na godzinowy
def format_time(minuty):
    godzina = int(minuty // 60 + 8)  # start o 8:00
    minuta = int(minuty % 60)
    return f"{godzina:02}:{minuta:02}"

class Przychodnia:
    def __init__(self, env, liczba_lekarzy):
        self.env = env
        self.lekarz = simpy.PriorityResource(env, capacity=liczba_lekarzy)  # Zasób z priorytetem
        self.patients_in_queue = 0
        self.patients_in_service = 0

    def wizyta(self, pacjent):
        """Symulacja wizyty pacjenta, która trwa losowo zgodnie z rozkładem wykładniczym"""
        self.patients_in_service += 1
        update_data(self.env.now, self.patients_in_queue, self.patients_in_service)  # Zaktualizuj dane do wykresu

        czas_wizyty = random.expovariate(MU)  # czas wizyty zgodnie z rozkładem wykładniczym
        yield self.env.timeout(czas_wizyty)

        self.patients_in_service -= 1
        update_data(self.env.now, self.patients_in_queue, self.patients_in_service)  # Zaktualizuj dane po zakończeniu wizyty
        print(f"{pacjent['name']} skończył wizytę o {format_time(self.env.now)}.")

def pacjent(env, name, przychodnia, priorytet):
    """Funkcja dla pacjenta, który przychodzi do lekarza"""
    global total_patients
    arrival_time = env.now
    print(f"{name} przyszedł do przychodni o {format_time(arrival_time)} (priorytet: {priorytet}).")

    przychodnia.patients_in_queue += 1
    update_data(env.now, przychodnia.patients_in_queue, przychodnia.patients_in_service)  # Zaktualizuj dane do wykresu

    with przychodnia.lekarz.request(priority=priorytet) as request:
        yield request
        przychodnia.patients_in_queue -= 1
        waiting_time = env.now - arrival_time
        waiting_times.append(waiting_time)

        # Zaokrąglenie czasu oczekiwania
        print(f"{name} zaczyna wizytę o {format_time(env.now)}. Czas oczekiwania: {waiting_time:.2f} minut.")

        yield env.process(przychodnia.wizyta({'name': name}))
        total_patients += 1

def proces_nadejscia(env, przychodnia):
    """Generowanie pacjentów zgodnie z procesem Poissona"""
    i = 0
    while True:
        czas_nastepnego = random.expovariate(LAMBDA / 60)  # czas między pacjentami (w minutach)
        yield env.timeout(czas_nastepnego)
        i += 1

        # Wybieramy losowy priorytet (1 - wyższy priorytet, 2 - niższy priorytet)
        priorytet = random.choice([1, 2])
        name = f"Pacjent {i} {'(priorytet)' if priorytet == 1 else ''}"

        env.process(pacjent(env, name, przychodnia, priorytet))

def update_data(time, patients_in_queue, patients_in_service):
    """Funkcja do aktualizacji danych do wykresów"""
    time_data.append(time)
    queue_data.append(patients_in_queue)
    in_service_data.append(patients_in_service)

# Główna funkcja symulacji
def run_simulation():
    global total_patients, waiting_times
    env = simpy.Environment()
    przychodnia = Przychodnia(env, LEKARZE)  # Tworzymy przychodnię z 3 lekarzami

    # Start generowania pacjentów
    env.process(proces_nadejscia(env, przychodnia))

    # Uruchomienie symulacji
    env.run(until=SIM_TIME)

    # Wyniki symulacji
    print("\nSymulacja zakończona.")
    print(f"Liczba obsłużonych pacjentów: {total_patients}")
    if waiting_times:
        print(f"Średni czas oczekiwania: {np.mean(waiting_times):.2f} minut")
    else:
        print("Nie było żadnych pacjentów w kolejce.")

# Uruchomienie symulacji
if __name__ == "__main__":
    run_simulation()

    # Wykres 1: Liczba pacjentów w kolejce i obsługiwanych
    plt.figure(figsize=(10, 5))
    plt.step(time_data, queue_data, label='Liczba pacjentów w kolejce', color='blue', where='post')
    plt.step(time_data, in_service_data, label='Liczba pacjentów obsługiwanych', color='green', where='post')
    plt.xlabel("Czas [minuty]")
    plt.ylabel("Liczba pacjentów")
    plt.title("Długość kolejki i liczba pacjentów obsługiwanych w czasie")
    plt.legend()
    plt.grid()
    plt.show()

    # Wykres 2: Średnia długość kolejki w zależności od intensywności (Ro)
    ro_values = np.linspace(0.1, 4.0, 40)
    avg_queue_lengths = []

    for ro in ro_values:
        # Przy obciążeniu Ro, liczba pacjentów oczekujących
        avg_queue_length = LAMBDA / (LEKARZE * MU * ro)
        avg_queue_lengths.append(avg_queue_length)

    plt.figure(figsize=(10, 5))
    plt.plot(ro_values, avg_queue_lengths, label='Średnia długość kolejki', color='darkblue')
    plt.xlabel("Stosunek intensywności przychodzeń (Ro)")
    plt.ylabel("Średnia długość kolejki")
    plt.title("Zależność średniej długości kolejki od stosunku Ro")
    plt.legend()
    plt.grid()
    plt.show()
# Out:
# Pacjent 1 (priorytet) przyszedł do przychodni o 08:09 (priorytet: 1).
# Pacjent 1 (priorytet) zaczyna wizytę o 08:09. Czas oczekiwania: 0.00 minut.
# Pacjent 2  przyszedł do przychodni o 08:22 (priorytet: 2).
# Pacjent 2  zaczyna wizytę o 08:22. Czas oczekiwania: 0.00 minut.
# Pacjent 3 (priorytet) przyszedł do przychodni o 08:23 (priorytet: 1).
# Pacjent 3 (priorytet) zaczyna wizytę o 08:23. Czas oczekiwania: 0.00 minut.
# Pacjent 4 (priorytet) przyszedł do przychodni o 08:24 (priorytet: 1).
# Pacjent 3 (priorytet) skończył wizytę o 08:24.
# Pacjent 4 (priorytet) zaczyna wizytę o 08:24. Czas oczekiwania: 0.05 minut.
# Pacjent 2  skończył wizytę o 08:28.
# Pacjent 5  przyszedł do przychodni o 08:32 (priorytet: 2).
# Pacjent 5  zaczyna wizytę o 08:32. Czas oczekiwania: 0.00 minut.
# Pacjent 5  skończył wizytę o 08:34.
# Pacjent 6 (priorytet) przyszedł do przychodni o 08:38 (priorytet: 1).
# Pacjent 6 (priorytet) zaczyna wizytę o 08:38. Czas oczekiwania: 0.00 minut.
# Pacjent 7 (priorytet) przyszedł do przychodni o 08:48 (priorytet: 1).
# Pacjent 8  przyszedł do przychodni o 08:51 (priorytet: 2).
# Pacjent 6 (priorytet) skończył wizytę o 08:52.
# Pacjent 7 (priorytet) zaczyna wizytę o 08:52. Czas oczekiwania: 3.46 minut.
# Pacjent 9 (priorytet) przyszedł do przychodni o 08:56 (priorytet: 1).
# Pacjent 10  przyszedł do przychodni o 08:57 (priorytet: 2).
# Pacjent 7 (priorytet) skończył wizytę o 09:07.
# Pacjent 9 (priorytet) zaczyna wizytę o 09:07. Czas oczekiwania: 10.85 minut.
# Pacjent 11 (priorytet) przyszedł do przychodni o 09:11 (priorytet: 1).
# Pacjent 1 (priorytet) skończył wizytę o 09:14.
# Pacjent 11 (priorytet) zaczyna wizytę o 09:14. Czas oczekiwania: 3.21 minut.
# Pacjent 9 (priorytet) skończył wizytę o 09:19.
# Pacjent 8  zaczyna wizytę o 09:19. Czas oczekiwania: 28.17 minut.
# Pacjent 4 (priorytet) skończył wizytę o 09:23.
# Pacjent 10  zaczyna wizytę o 09:23. Czas oczekiwania: 26.10 minut.
# Pacjent 10  skończył wizytę o 09:28.
# Pacjent 12  przyszedł do przychodni o 09:33 (priorytet: 2).
# Pacjent 12  zaczyna wizytę o 09:33. Czas oczekiwania: 0.00 minut.
# Pacjent 11 (priorytet) skończył wizytę o 09:34.
# Pacjent 8  skończył wizytę o 09:38.
# Pacjent 13 (priorytet) przyszedł do przychodni o 09:55 (priorytet: 1).
# Pacjent 13 (priorytet) zaczyna wizytę o 09:55. Czas oczekiwania: 0.00 minut.
# Pacjent 12  skończył wizytę o 09:57.
# Pacjent 13 (priorytet) skończył wizytę o 09:57.
# Pacjent 14 (priorytet) przyszedł do przychodni o 10:11 (priorytet: 1).
# Pacjent 14 (priorytet) zaczyna wizytę o 10:11. Czas oczekiwania: 0.00 minut.
# Pacjent 15 (priorytet) przyszedł do przychodni o 10:27 (priorytet: 1).
# Pacjent 15 (priorytet) zaczyna wizytę o 10:27. Czas oczekiwania: 0.00 minut.
# Pacjent 16 (priorytet) przyszedł do przychodni o 10:28 (priorytet: 1).
# Pacjent 16 (priorytet) zaczyna wizytę o 10:28. Czas oczekiwania: 0.00 minut.
# Pacjent 14 (priorytet) skończył wizytę o 10:29.
# Pacjent 17  przyszedł do przychodni o 10:34 (priorytet: 2).
# Pacjent 17  zaczyna wizytę o 10:34. Czas oczekiwania: 0.00 minut.
# Pacjent 17  skończył wizytę o 10:36.
# Pacjent 18  przyszedł do przychodni o 10:47 (priorytet: 2).
# Pacjent 18  zaczyna wizytę o 10:47. Czas oczekiwania: 0.00 minut.
# Pacjent 19 (priorytet) przyszedł do przychodni o 10:49 (priorytet: 1).
# Pacjent 18  skończył wizytę o 10:50.
# Pacjent 19 (priorytet) zaczyna wizytę o 10:50. Czas oczekiwania: 1.31 minut.
# Pacjent 19 (priorytet) skończył wizytę o 10:52.
# Pacjent 16 (priorytet) skończył wizytę o 10:54.
# Pacjent 15 (priorytet) skończył wizytę o 10:58.
# Pacjent 20  przyszedł do przychodni o 11:18 (priorytet: 2).
# Pacjent 20  zaczyna wizytę o 11:18. Czas oczekiwania: 0.00 minut.
# Pacjent 21 (priorytet) przyszedł do przychodni o 11:19 (priorytet: 1).
# Pacjent 21 (priorytet) zaczyna wizytę o 11:19. Czas oczekiwania: 0.00 minut.
# Pacjent 20  skończył wizytę o 11:23.
# Pacjent 22 (priorytet) przyszedł do przychodni o 11:23 (priorytet: 1).
# Pacjent 22 (priorytet) zaczyna wizytę o 11:23. Czas oczekiwania: 0.00 minut.
# Pacjent 21 (priorytet) skończył wizytę o 11:24.
# Pacjent 22 (priorytet) skończył wizytę o 11:27.
# Pacjent 23  przyszedł do przychodni o 11:27 (priorytet: 2).
# Pacjent 23  zaczyna wizytę o 11:27. Czas oczekiwania: 0.00 minut.
# Pacjent 24 (priorytet) przyszedł do przychodni o 11:31 (priorytet: 1).
# Pacjent 24 (priorytet) zaczyna wizytę o 11:31. Czas oczekiwania: 0.00 minut.
# Pacjent 24 (priorytet) skończył wizytę o 11:34.
# Pacjent 23  skończył wizytę o 11:36.
# Pacjent 25 (priorytet) przyszedł do przychodni o 11:44 (priorytet: 1).
# Pacjent 25 (priorytet) zaczyna wizytę o 11:44. Czas oczekiwania: 0.00 minut.
# Pacjent 25 (priorytet) skończył wizytę o 11:45.
# Pacjent 26  przyszedł do przychodni o 11:48 (priorytet: 2).
# Pacjent 26  zaczyna wizytę o 11:48. Czas oczekiwania: 0.00 minut.
# Pacjent 27 (priorytet) przyszedł do przychodni o 11:56 (priorytet: 1).
# Pacjent 27 (priorytet) zaczyna wizytę o 11:56. Czas oczekiwania: 0.00 minut.
# Pacjent 28  przyszedł do przychodni o 12:02 (priorytet: 2).
# Pacjent 28  zaczyna wizytę o 12:02. Czas oczekiwania: 0.00 minut.
# Pacjent 27 (priorytet) skończył wizytę o 12:08.
# Pacjent 26  skończył wizytę o 12:17.
# Pacjent 28  skończył wizytę o 12:17.
# Pacjent 29 (priorytet) przyszedł do przychodni o 12:33 (priorytet: 1).
# Pacjent 29 (priorytet) zaczyna wizytę o 12:33. Czas oczekiwania: 0.00 minut.
# Pacjent 30 (priorytet) przyszedł do przychodni o 12:36 (priorytet: 1).
# Pacjent 30 (priorytet) zaczyna wizytę o 12:36. Czas oczekiwania: 0.00 minut.
# Pacjent 29 (priorytet) skończył wizytę o 12:38.
# Pacjent 31 (priorytet) przyszedł do przychodni o 12:40 (priorytet: 1).
# Pacjent 31 (priorytet) zaczyna wizytę o 12:40. Czas oczekiwania: 0.00 minut.
# Pacjent 31 (priorytet) skończył wizytę o 12:56.
# Pacjent 30 (priorytet) skończył wizytę o 12:56.
# Pacjent 32  przyszedł do przychodni o 12:56 (priorytet: 2).
# Pacjent 32  zaczyna wizytę o 12:56. Czas oczekiwania: 0.00 minut.
# Pacjent 33 (priorytet) przyszedł do przychodni o 13:05 (priorytet: 1).
# Pacjent 33 (priorytet) zaczyna wizytę o 13:05. Czas oczekiwania: 0.00 minut.
# Pacjent 34 (priorytet) przyszedł do przychodni o 13:09 (priorytet: 1).
# Pacjent 34 (priorytet) zaczyna wizytę o 13:09. Czas oczekiwania: 0.00 minut.
# Pacjent 33 (priorytet) skończył wizytę o 13:10.
# Pacjent 32  skończył wizytę o 13:12.
# Pacjent 34 (priorytet) skończył wizytę o 13:13.
# Pacjent 35  przyszedł do przychodni o 13:28 (priorytet: 2).
# Pacjent 35  zaczyna wizytę o 13:28. Czas oczekiwania: 0.00 minut.
# Pacjent 36 (priorytet) przyszedł do przychodni o 13:30 (priorytet: 1).
# Pacjent 36 (priorytet) zaczyna wizytę o 13:30. Czas oczekiwania: 0.00 minut.
# Pacjent 36 (priorytet) skończył wizytę o 13:35.
# Pacjent 37 (priorytet) przyszedł do przychodni o 14:13 (priorytet: 1).
# Pacjent 37 (priorytet) zaczyna wizytę o 14:13. Czas oczekiwania: 0.00 minut.
# Pacjent 38  przyszedł do przychodni o 14:18 (priorytet: 2).
# Pacjent 38  zaczyna wizytę o 14:18. Czas oczekiwania: 0.00 minut.
# Pacjent 39  przyszedł do przychodni o 14:20 (priorytet: 2).
# Pacjent 38  skończył wizytę o 14:32.
# Pacjent 39  zaczyna wizytę o 14:32. Czas oczekiwania: 12.24 minut.
# Pacjent 39  skończył wizytę o 14:34.
# Pacjent 35  skończył wizytę o 14:42.
# Pacjent 37 (priorytet) skończył wizytę o 14:46.
# Pacjent 40  przyszedł do przychodni o 15:18 (priorytet: 2).
# Pacjent 40  zaczyna wizytę o 15:18. Czas oczekiwania: 0.00 minut.
# Pacjent 40  skończył wizytę o 15:36.
# Pacjent 41  przyszedł do przychodni o 15:44 (priorytet: 2).
# Pacjent 41  zaczyna wizytę o 15:44. Czas oczekiwania: 0.00 minut.
# Pacjent 41  skończył wizytę o 15:47.
# Pacjent 42 (priorytet) przyszedł do przychodni o 15:48 (priorytet: 1).
# Pacjent 42 (priorytet) zaczyna wizytę o 15:48. Czas oczekiwania: 0.00 minut.
# Pacjent 43  przyszedł do przychodni o 15:49 (priorytet: 2).
# Pacjent 43  zaczyna wizytę o 15:49. Czas oczekiwania: 0.00 minut.
# Pacjent 44  przyszedł do przychodni o 15:56 (priorytet: 2).
# Pacjent 44  zaczyna wizytę o 15:56. Czas oczekiwania: 0.00 minut.
# Pacjent 44  skończył wizytę o 15:58.
#
# Symulacja zakończona.
# Liczba obsłużonych pacjentów: 42
# Średni czas oczekiwania: 1.94 minut

# %%
import simpy
import random
import numpy as np
import matplotlib.pyplot as plt

# Parametry symulacji
LAMBDA = 15  # średnia liczba pacjentów na godzinę (przychodzą zgodnie z procesem Poissona)
MU = 1 / 15  # średni czas wizyty wynosi 15 minut (rozkład wykładniczy)
SIM_TIME = 8 * 60  # symulacja 8 godzin (w minutach)
LEKARZE = 3  # liczba lekarzy (kanałów)
MAX_QUEUE_SIZE = 10  # maksymalna pojemność kolejki

# Zmienne do śledzenia liczby pacjentów
total_patients = 0
waiting_times = []
rejected_patients = 0  # Liczba odrzuconych pacjentów

# Zmienne do przechowywania danych dla wykresów
time_data = []
queue_data = []
in_service_data = []
rejected_data = []  # Liczba odrzuconych pacjentów w czasie

# Funkcja przeliczająca czas minutowy na godzinowy
def format_time(minuty):
    godzina = int(minuty // 60 + 8)  # start o 8:00
    minuta = int(minuty % 60)
    return f"{godzina:02}:{minuta:02}"

class Przychodnia:
    def __init__(self, env, liczba_lekarzy):
        self.env = env
        self.lekarz = simpy.PriorityResource(env, capacity=liczba_lekarzy)  # Zasób z priorytetem
        self.patients_in_queue = 0
        self.patients_in_service = 0

    def wizyta(self, pacjent):
        """Symulacja wizyty pacjenta, która trwa losowo zgodnie z rozkładem wykładniczym"""
        self.patients_in_service += 1
        update_data(self.env.now, self.patients_in_queue, self.patients_in_service)  # Zaktualizuj dane do wykresu

        czas_wizyty = random.expovariate(MU)  # czas wizyty zgodnie z rozkładem wykładniczym
        yield self.env.timeout(czas_wizyty)

        self.patients_in_service -= 1
        update_data(self.env.now, self.patients_in_queue, self.patients_in_service)  # Zaktualizuj dane po zakończeniu wizyty
        print(f"{pacjent['name']} skończył wizytę o {format_time(self.env.now)}.")

def pacjent(env, name, przychodnia, priorytet):
    """Funkcja dla pacjenta, który przychodzi do lekarza"""
    global total_patients, rejected_patients
    arrival_time = env.now

    # Sprawdzenie, czy kolejka jest pełna
    if przychodnia.patients_in_queue >= MAX_QUEUE_SIZE:
        print(f"{name} został odrzucony o {format_time(arrival_time)} z powodu pełnej kolejki.")
        rejected_patients += 1
        rejected_data.append((env.now, rejected_patients))
        return  # Pacjent jest odrzucony i kończy działanie

    print(f"{name} przyszedł do przychodni o {format_time(arrival_time)} (priorytet: {priorytet}).")
    przychodnia.patients_in_queue += 1
    update_data(env.now, przychodnia.patients_in_queue, przychodnia.patients_in_service)  # Zaktualizuj dane do wykresu

    with przychodnia.lekarz.request(priority=priorytet) as request:
        yield request
        przychodnia.patients_in_queue -= 1
        waiting_time = env.now - arrival_time
        waiting_times.append(waiting_time)

        print(f"{name} zaczyna wizytę o {format_time(env.now)}. Czas oczekiwania: {waiting_time:.2f} minut.")

        yield env.process(przychodnia.wizyta({'name': name}))
        total_patients += 1

def proces_nadejscia(env, przychodnia):
    """Generowanie pacjentów zgodnie z procesem Poissona"""
    i = 0
    while True:
        czas_nastepnego = random.expovariate(LAMBDA / 60)  # czas między pacjentami (w minutach)
        yield env.timeout(czas_nastepnego)
        i += 1

        # Wybieramy losowy priorytet (1 - najwyższy, 2 - średni, 3 - niski)
        priorytet = random.choice([1, 2, 3])
        name = f"Pacjent {i} (Priorytet {priorytet})"

        env.process(pacjent(env, name, przychodnia, priorytet))

def update_data(time, patients_in_queue, patients_in_service):
    """Funkcja do aktualizacji danych do wykresów"""
    time_data.append(time)
    queue_data.append(patients_in_queue)
    in_service_data.append(patients_in_service)

# Główna funkcja symulacji
def run_simulation():
    global total_patients, waiting_times, rejected_patients
    env = simpy.Environment()
    przychodnia = Przychodnia(env, LEKARZE)  # Tworzymy przychodnię z 3 lekarzami

    # Start generowania pacjentów
    env.process(proces_nadejscia(env, przychodnia))

    # Uruchomienie symulacji
    env.run(until=SIM_TIME)

    # Wyniki symulacji
    print("\nSymulacja zakończona.")
    print(f"Liczba obsłużonych pacjentów: {total_patients}")
    print(f"Liczba odrzuconych pacjentów: {rejected_patients}")
    if waiting_times:
        print(f"Średni czas oczekiwania: {np.mean(waiting_times):.2f} minut")
    else:
        print("Nie było żadnych pacjentów w kolejce.")

# Uruchomienie symulacji
if __name__ == "__main__":
    run_simulation()

    # Wykres 1: Liczba pacjentów w kolejce i obsługiwanych
    plt.figure(figsize=(10, 5))
    plt.step(time_data, queue_data, label='Liczba pacjentów w kolejce', color='blue', where='post')
    plt.step(time_data, in_service_data, label='Liczba pacjentów obsługiwanych', color='green', where='post')
    plt.xlabel("Czas [minuty]")
    plt.ylabel("Liczba pacjentów")
    plt.title("Długość kolejki i liczba pacjentów obsługiwanych w czasie")
    plt.legend()
    plt.grid()
    plt.show()

    # Wykres 2: Liczba odrzuconych pacjentów w czasie
    rejected_times, rejected_counts = zip(*rejected_data) if rejected_data else ([], [])
    plt.figure(figsize=(10, 5))
    plt.step(rejected_times, rejected_counts, label='Liczba odrzuconych pacjentów', color='red', where='post')
    plt.xlabel("Czas [minuty]")
    plt.ylabel("Liczba odrzuconych pacjentów")
    plt.title("Liczba odrzuconych pacjentów w czasie")
    plt.legend()
    plt.grid()
    plt.show()
# Out:
# Pacjent 1 (Priorytet 2) przyszedł do przychodni o 08:00 (priorytet: 2).
# Pacjent 1 (Priorytet 2) zaczyna wizytę o 08:00. Czas oczekiwania: 0.00 minut.
# Pacjent 1 (Priorytet 2) skończył wizytę o 08:00.
# Pacjent 2 (Priorytet 3) przyszedł do przychodni o 08:02 (priorytet: 3).
# Pacjent 2 (Priorytet 3) zaczyna wizytę o 08:02. Czas oczekiwania: 0.00 minut.
# Pacjent 3 (Priorytet 2) przyszedł do przychodni o 08:05 (priorytet: 2).
# Pacjent 3 (Priorytet 2) zaczyna wizytę o 08:05. Czas oczekiwania: 0.00 minut.
# Pacjent 4 (Priorytet 2) przyszedł do przychodni o 08:08 (priorytet: 2).
# Pacjent 4 (Priorytet 2) zaczyna wizytę o 08:08. Czas oczekiwania: 0.00 minut.
# Pacjent 5 (Priorytet 2) przyszedł do przychodni o 08:11 (priorytet: 2).
# Pacjent 4 (Priorytet 2) skończył wizytę o 08:17.
# Pacjent 5 (Priorytet 2) zaczyna wizytę o 08:17. Czas oczekiwania: 5.24 minut.
# Pacjent 6 (Priorytet 2) przyszedł do przychodni o 08:18 (priorytet: 2).
# Pacjent 7 (Priorytet 1) przyszedł do przychodni o 08:22 (priorytet: 1).
# Pacjent 8 (Priorytet 3) przyszedł do przychodni o 08:23 (priorytet: 3).
# Pacjent 5 (Priorytet 2) skończył wizytę o 08:23.
# Pacjent 7 (Priorytet 1) zaczyna wizytę o 08:23. Czas oczekiwania: 1.20 minut.
# Pacjent 9 (Priorytet 1) przyszedł do przychodni o 08:24 (priorytet: 1).
# Pacjent 10 (Priorytet 2) przyszedł do przychodni o 08:27 (priorytet: 2).
# Pacjent 2 (Priorytet 3) skończył wizytę o 08:27.
# Pacjent 9 (Priorytet 1) zaczyna wizytę o 08:27. Czas oczekiwania: 3.04 minut.
# Pacjent 9 (Priorytet 1) skończył wizytę o 08:30.
# Pacjent 6 (Priorytet 2) zaczyna wizytę o 08:30. Czas oczekiwania: 11.90 minut.
# Pacjent 11 (Priorytet 1) przyszedł do przychodni o 08:31 (priorytet: 1).
# Pacjent 12 (Priorytet 3) przyszedł do przychodni o 08:32 (priorytet: 3).
# Pacjent 7 (Priorytet 1) skończył wizytę o 08:41.
# Pacjent 11 (Priorytet 1) zaczyna wizytę o 08:41. Czas oczekiwania: 10.26 minut.
# Pacjent 13 (Priorytet 1) przyszedł do przychodni o 08:42 (priorytet: 1).
# Pacjent 14 (Priorytet 2) przyszedł do przychodni o 08:46 (priorytet: 2).
# Pacjent 6 (Priorytet 2) skończył wizytę o 08:50.
# Pacjent 13 (Priorytet 1) zaczyna wizytę o 08:50. Czas oczekiwania: 7.87 minut.
# Pacjent 11 (Priorytet 1) skończył wizytę o 08:51.
# Pacjent 10 (Priorytet 2) zaczyna wizytę o 08:51. Czas oczekiwania: 24.66 minut.
# Pacjent 13 (Priorytet 1) skończył wizytę o 08:53.
# Pacjent 14 (Priorytet 2) zaczyna wizytę o 08:53. Czas oczekiwania: 6.29 minut.
# Pacjent 15 (Priorytet 1) przyszedł do przychodni o 08:53 (priorytet: 1).
# Pacjent 16 (Priorytet 2) przyszedł do przychodni o 08:57 (priorytet: 2).
# Pacjent 17 (Priorytet 2) przyszedł do przychodni o 09:00 (priorytet: 2).
# Pacjent 14 (Priorytet 2) skończył wizytę o 09:05.
# Pacjent 15 (Priorytet 1) zaczyna wizytę o 09:05. Czas oczekiwania: 11.08 minut.
# Pacjent 18 (Priorytet 1) przyszedł do przychodni o 09:08 (priorytet: 1).
# Pacjent 19 (Priorytet 3) przyszedł do przychodni o 09:09 (priorytet: 3).
# Pacjent 20 (Priorytet 2) przyszedł do przychodni o 09:11 (priorytet: 2).
# Pacjent 21 (Priorytet 1) przyszedł do przychodni o 09:11 (priorytet: 1).
# Pacjent 22 (Priorytet 2) przyszedł do przychodni o 09:12 (priorytet: 2).
# Pacjent 15 (Priorytet 1) skończył wizytę o 09:14.
# Pacjent 18 (Priorytet 1) zaczyna wizytę o 09:14. Czas oczekiwania: 6.09 minut.
# Pacjent 10 (Priorytet 2) skończył wizytę o 09:15.
# Pacjent 21 (Priorytet 1) zaczyna wizytę o 09:15. Czas oczekiwania: 3.60 minut.
# Pacjent 23 (Priorytet 3) przyszedł do przychodni o 09:17 (priorytet: 3).
# Pacjent 18 (Priorytet 1) skończył wizytę o 09:19.
# Pacjent 16 (Priorytet 2) zaczyna wizytę o 09:19. Czas oczekiwania: 22.59 minut.
# Pacjent 16 (Priorytet 2) skończył wizytę o 09:23.
# Pacjent 17 (Priorytet 2) zaczyna wizytę o 09:23. Czas oczekiwania: 22.55 minut.
# Pacjent 24 (Priorytet 1) przyszedł do przychodni o 09:25 (priorytet: 1).
# Pacjent 21 (Priorytet 1) skończył wizytę o 09:27.
# Pacjent 24 (Priorytet 1) zaczyna wizytę o 09:27. Czas oczekiwania: 2.05 minut.
# Pacjent 25 (Priorytet 3) przyszedł do przychodni o 09:28 (priorytet: 3).
# Pacjent 26 (Priorytet 3) przyszedł do przychodni o 09:32 (priorytet: 3).
# Pacjent 27 (Priorytet 3) przyszedł do przychodni o 09:33 (priorytet: 3).
# Pacjent 28 (Priorytet 3) przyszedł do przychodni o 09:35 (priorytet: 3).
# Pacjent 29 (Priorytet 3) został odrzucony o 09:36 z powodu pełnej kolejki.
# Pacjent 30 (Priorytet 1) został odrzucony o 09:36 z powodu pełnej kolejki.
# Pacjent 24 (Priorytet 1) skończył wizytę o 09:37.
# Pacjent 20 (Priorytet 2) zaczyna wizytę o 09:37. Czas oczekiwania: 26.29 minut.
# Pacjent 31 (Priorytet 2) przyszedł do przychodni o 09:40 (priorytet: 2).
# Pacjent 32 (Priorytet 1) został odrzucony o 09:43 z powodu pełnej kolejki.
# Pacjent 20 (Priorytet 2) skończył wizytę o 09:44.
# Pacjent 22 (Priorytet 2) zaczyna wizytę o 09:44. Czas oczekiwania: 32.01 minut.
# Pacjent 17 (Priorytet 2) skończył wizytę o 09:47.
# Pacjent 31 (Priorytet 2) zaczyna wizytę o 09:47. Czas oczekiwania: 7.31 minut.
# Pacjent 22 (Priorytet 2) skończył wizytę o 09:54.
# Pacjent 8 (Priorytet 3) zaczyna wizytę o 09:54. Czas oczekiwania: 90.81 minut.
# Pacjent 8 (Priorytet 3) skończył wizytę o 09:59.
# Pacjent 12 (Priorytet 3) zaczyna wizytę o 09:59. Czas oczekiwania: 87.39 minut.
# Pacjent 33 (Priorytet 2) przyszedł do przychodni o 10:15 (priorytet: 2).
# Pacjent 34 (Priorytet 3) przyszedł do przychodni o 10:18 (priorytet: 3).
# Pacjent 35 (Priorytet 3) przyszedł do przychodni o 10:23 (priorytet: 3).
# Pacjent 12 (Priorytet 3) skończył wizytę o 10:25.
# Pacjent 33 (Priorytet 2) zaczyna wizytę o 10:25. Czas oczekiwania: 9.69 minut.
# Pacjent 36 (Priorytet 2) przyszedł do przychodni o 10:25 (priorytet: 2).
# Pacjent 37 (Priorytet 2) przyszedł do przychodni o 10:27 (priorytet: 2).
# Pacjent 31 (Priorytet 2) skończył wizytę o 10:28.
# Pacjent 36 (Priorytet 2) zaczyna wizytę o 10:28. Czas oczekiwania: 3.68 minut.
# Pacjent 38 (Priorytet 2) przyszedł do przychodni o 10:29 (priorytet: 2).
# Pacjent 39 (Priorytet 3) został odrzucony o 10:29 z powodu pełnej kolejki.
# Pacjent 3 (Priorytet 2) skończył wizytę o 10:30.
# Pacjent 37 (Priorytet 2) zaczyna wizytę o 10:30. Czas oczekiwania: 2.83 minut.
# Pacjent 36 (Priorytet 2) skończył wizytę o 10:31.
# Pacjent 38 (Priorytet 2) zaczyna wizytę o 10:31. Czas oczekiwania: 2.16 minut.
# Pacjent 40 (Priorytet 3) przyszedł do przychodni o 10:33 (priorytet: 3).
# Pacjent 41 (Priorytet 2) przyszedł do przychodni o 10:34 (priorytet: 2).
# Pacjent 42 (Priorytet 3) został odrzucony o 10:35 z powodu pełnej kolejki.
# Pacjent 37 (Priorytet 2) skończył wizytę o 10:44.
# Pacjent 41 (Priorytet 2) zaczyna wizytę o 10:44. Czas oczekiwania: 9.84 minut.
# Pacjent 43 (Priorytet 1) przyszedł do przychodni o 10:45 (priorytet: 1).
# Pacjent 38 (Priorytet 2) skończył wizytę o 10:46.
# Pacjent 43 (Priorytet 1) zaczyna wizytę o 10:46. Czas oczekiwania: 1.22 minut.
# Pacjent 41 (Priorytet 2) skończył wizytę o 10:53.
# Pacjent 19 (Priorytet 3) zaczyna wizytę o 10:53. Czas oczekiwania: 103.25 minut.
# Pacjent 44 (Priorytet 3) przyszedł do przychodni o 10:54 (priorytet: 3).
# Pacjent 45 (Priorytet 1) przyszedł do przychodni o 10:58 (priorytet: 1).
# Pacjent 19 (Priorytet 3) skończył wizytę o 11:00.
# Pacjent 45 (Priorytet 1) zaczyna wizytę o 11:00. Czas oczekiwania: 2.00 minut.
# Pacjent 46 (Priorytet 2) przyszedł do przychodni o 11:01 (priorytet: 2).
# Pacjent 47 (Priorytet 1) został odrzucony o 11:01 z powodu pełnej kolejki.
# Pacjent 33 (Priorytet 2) skończył wizytę o 11:07.
# Pacjent 46 (Priorytet 2) zaczyna wizytę o 11:07. Czas oczekiwania: 6.84 minut.
# Pacjent 48 (Priorytet 2) przyszedł do przychodni o 11:08 (priorytet: 2).
# Pacjent 49 (Priorytet 3) został odrzucony o 11:13 z powodu pełnej kolejki.
# Pacjent 50 (Priorytet 1) został odrzucony o 11:18 z powodu pełnej kolejki.
# Pacjent 51 (Priorytet 2) został odrzucony o 11:26 z powodu pełnej kolejki.
# Pacjent 46 (Priorytet 2) skończył wizytę o 11:27.
# Pacjent 48 (Priorytet 2) zaczyna wizytę o 11:27. Czas oczekiwania: 19.26 minut.
# Pacjent 48 (Priorytet 2) skończył wizytę o 11:27.
# Pacjent 23 (Priorytet 3) zaczyna wizytę o 11:27. Czas oczekiwania: 130.16 minut.
# Pacjent 23 (Priorytet 3) skończył wizytę o 11:28.
# Pacjent 25 (Priorytet 3) zaczyna wizytę o 11:28. Czas oczekiwania: 120.27 minut.
# Pacjent 52 (Priorytet 3) przyszedł do przychodni o 11:29 (priorytet: 3).
# Pacjent 45 (Priorytet 1) skończył wizytę o 11:29.
# Pacjent 26 (Priorytet 3) zaczyna wizytę o 11:29. Czas oczekiwania: 117.30 minut.
# Pacjent 43 (Priorytet 1) skończył wizytę o 11:30.
# Pacjent 27 (Priorytet 3) zaczyna wizytę o 11:30. Czas oczekiwania: 117.24 minut.
# Pacjent 26 (Priorytet 3) skończył wizytę o 11:31.
# Pacjent 28 (Priorytet 3) zaczyna wizytę o 11:31. Czas oczekiwania: 115.55 minut.
# Pacjent 53 (Priorytet 1) przyszedł do przychodni o 11:34 (priorytet: 1).
# Pacjent 54 (Priorytet 1) przyszedł do przychodni o 11:36 (priorytet: 1).
# Pacjent 55 (Priorytet 1) przyszedł do przychodni o 11:36 (priorytet: 1).
# Pacjent 56 (Priorytet 3) przyszedł do przychodni o 11:41 (priorytet: 3).
# Pacjent 57 (Priorytet 3) przyszedł do przychodni o 11:42 (priorytet: 3).
# Pacjent 28 (Priorytet 3) skończył wizytę o 11:45.
# Pacjent 53 (Priorytet 1) zaczyna wizytę o 11:45. Czas oczekiwania: 10.80 minut.
# Pacjent 58 (Priorytet 1) przyszedł do przychodni o 11:46 (priorytet: 1).
# Pacjent 59 (Priorytet 1) został odrzucony o 11:46 z powodu pełnej kolejki.
# Pacjent 27 (Priorytet 3) skończył wizytę o 12:01.
# Pacjent 54 (Priorytet 1) zaczyna wizytę o 12:01. Czas oczekiwania: 24.97 minut.
# Pacjent 60 (Priorytet 2) przyszedł do przychodni o 12:03 (priorytet: 2).
# Pacjent 61 (Priorytet 3) został odrzucony o 12:04 z powodu pełnej kolejki.
# Pacjent 62 (Priorytet 1) został odrzucony o 12:04 z powodu pełnej kolejki.
# Pacjent 25 (Priorytet 3) skończył wizytę o 12:06.
# Pacjent 55 (Priorytet 1) zaczyna wizytę o 12:06. Czas oczekiwania: 29.77 minut.
# Pacjent 63 (Priorytet 2) przyszedł do przychodni o 12:06 (priorytet: 2).
# Pacjent 64 (Priorytet 2) został odrzucony o 12:07 z powodu pełnej kolejki.
# Pacjent 65 (Priorytet 2) został odrzucony o 12:08 z powodu pełnej kolejki.
# Pacjent 66 (Priorytet 1) został odrzucony o 12:12 z powodu pełnej kolejki.
# Pacjent 54 (Priorytet 1) skończył wizytę o 12:13.
# Pacjent 58 (Priorytet 1) zaczyna wizytę o 12:13. Czas oczekiwania: 26.82 minut.
# Pacjent 58 (Priorytet 1) skończył wizytę o 12:13.
# Pacjent 60 (Priorytet 2) zaczyna wizytę o 12:13. Czas oczekiwania: 9.49 minut.
# Pacjent 67 (Priorytet 2) przyszedł do przychodni o 12:15 (priorytet: 2).
# Pacjent 68 (Priorytet 3) przyszedł do przychodni o 12:19 (priorytet: 3).
# Pacjent 53 (Priorytet 1) skończył wizytę o 12:22.
# Pacjent 63 (Priorytet 2) zaczyna wizytę o 12:22. Czas oczekiwania: 16.21 minut.
# Pacjent 69 (Priorytet 1) przyszedł do przychodni o 12:27 (priorytet: 1).
# Pacjent 55 (Priorytet 1) skończył wizytę o 12:28.
# Pacjent 69 (Priorytet 1) zaczyna wizytę o 12:28. Czas oczekiwania: 0.28 minut.
# Pacjent 70 (Priorytet 2) przyszedł do przychodni o 12:30 (priorytet: 2).
# Pacjent 71 (Priorytet 1) został odrzucony o 12:33 z powodu pełnej kolejki.
# Pacjent 63 (Priorytet 2) skończył wizytę o 12:33.
# Pacjent 67 (Priorytet 2) zaczyna wizytę o 12:33. Czas oczekiwania: 18.21 minut.
# Pacjent 72 (Priorytet 1) przyszedł do przychodni o 12:35 (priorytet: 1).
# Pacjent 60 (Priorytet 2) skończył wizytę o 12:36.
# Pacjent 72 (Priorytet 1) zaczyna wizytę o 12:36. Czas oczekiwania: 0.96 minut.
# Pacjent 73 (Priorytet 1) przyszedł do przychodni o 12:36 (priorytet: 1).
# Pacjent 74 (Priorytet 1) został odrzucony o 12:41 z powodu pełnej kolejki.
# Pacjent 75 (Priorytet 1) został odrzucony o 12:41 z powodu pełnej kolejki.
# Pacjent 76 (Priorytet 3) został odrzucony o 12:42 z powodu pełnej kolejki.
# Pacjent 77 (Priorytet 1) został odrzucony o 12:45 z powodu pełnej kolejki.
# Pacjent 78 (Priorytet 1) został odrzucony o 12:47 z powodu pełnej kolejki.
# Pacjent 79 (Priorytet 3) został odrzucony o 12:48 z powodu pełnej kolejki.
# Pacjent 80 (Priorytet 1) został odrzucony o 12:48 z powodu pełnej kolejki.
# Pacjent 69 (Priorytet 1) skończył wizytę o 12:48.
# Pacjent 73 (Priorytet 1) zaczyna wizytę o 12:48. Czas oczekiwania: 12.61 minut.
# Pacjent 67 (Priorytet 2) skończył wizytę o 12:49.
# Pacjent 70 (Priorytet 2) zaczyna wizytę o 12:49. Czas oczekiwania: 19.46 minut.
# Pacjent 81 (Priorytet 3) przyszedł do przychodni o 12:51 (priorytet: 3).
# Pacjent 70 (Priorytet 2) skończył wizytę o 12:57.
# Pacjent 34 (Priorytet 3) zaczyna wizytę o 12:57. Czas oczekiwania: 159.07 minut.
# Pacjent 73 (Priorytet 1) skończył wizytę o 12:58.
# Pacjent 35 (Priorytet 3) zaczyna wizytę o 12:58. Czas oczekiwania: 155.14 minut.
# Pacjent 72 (Priorytet 1) skończył wizytę o 13:02.
# Pacjent 40 (Priorytet 3) zaczyna wizytę o 13:02. Czas oczekiwania: 149.29 minut.
# Pacjent 82 (Priorytet 2) przyszedł do przychodni o 13:06 (priorytet: 2).
# Pacjent 83 (Priorytet 2) przyszedł do przychodni o 13:09 (priorytet: 2).
# Pacjent 84 (Priorytet 3) przyszedł do przychodni o 13:10 (priorytet: 3).
# Pacjent 35 (Priorytet 3) skończył wizytę o 13:12.
# Pacjent 82 (Priorytet 2) zaczyna wizytę o 13:12. Czas oczekiwania: 5.13 minut.
# Pacjent 82 (Priorytet 2) skończył wizytę o 13:12.
# Pacjent 83 (Priorytet 2) zaczyna wizytę o 13:12. Czas oczekiwania: 3.08 minut.
# Pacjent 85 (Priorytet 2) przyszedł do przychodni o 13:18 (priorytet: 2).
# Pacjent 86 (Priorytet 1) przyszedł do przychodni o 13:19 (priorytet: 1).
# Pacjent 40 (Priorytet 3) skończył wizytę o 13:23.
# Pacjent 86 (Priorytet 1) zaczyna wizytę o 13:23. Czas oczekiwania: 4.33 minut.
# Pacjent 87 (Priorytet 1) przyszedł do przychodni o 13:25 (priorytet: 1).
# Pacjent 88 (Priorytet 3) przyszedł do przychodni o 13:30 (priorytet: 3).
# Pacjent 89 (Priorytet 2) został odrzucony o 13:31 z powodu pełnej kolejki.
# Pacjent 34 (Priorytet 3) skończył wizytę o 13:31.
# Pacjent 87 (Priorytet 1) zaczyna wizytę o 13:31. Czas oczekiwania: 6.58 minut.
# Pacjent 90 (Priorytet 1) przyszedł do przychodni o 13:32 (priorytet: 1).
# Pacjent 87 (Priorytet 1) skończył wizytę o 13:34.
# Pacjent 90 (Priorytet 1) zaczyna wizytę o 13:34. Czas oczekiwania: 1.16 minut.
# Pacjent 91 (Priorytet 1) przyszedł do przychodni o 13:35 (priorytet: 1).
# Pacjent 83 (Priorytet 2) skończył wizytę o 13:36.
# Pacjent 91 (Priorytet 1) zaczyna wizytę o 13:36. Czas oczekiwania: 1.12 minut.
# Pacjent 92 (Priorytet 3) przyszedł do przychodni o 13:41 (priorytet: 3).
# Pacjent 93 (Priorytet 2) został odrzucony o 13:42 z powodu pełnej kolejki.
# Pacjent 94 (Priorytet 3) został odrzucony o 13:45 z powodu pełnej kolejki.
# Pacjent 95 (Priorytet 3) został odrzucony o 13:47 z powodu pełnej kolejki.
# Pacjent 96 (Priorytet 3) został odrzucony o 13:47 z powodu pełnej kolejki.
# Pacjent 97 (Priorytet 1) został odrzucony o 13:48 z powodu pełnej kolejki.
# Pacjent 90 (Priorytet 1) skończył wizytę o 13:49.
# Pacjent 85 (Priorytet 2) zaczyna wizytę o 13:49. Czas oczekiwania: 30.47 minut.
# Pacjent 98 (Priorytet 2) przyszedł do przychodni o 13:51 (priorytet: 2).
# Pacjent 99 (Priorytet 1) został odrzucony o 13:51 z powodu pełnej kolejki.
# Pacjent 100 (Priorytet 1) został odrzucony o 13:51 z powodu pełnej kolejki.
# Pacjent 101 (Priorytet 2) został odrzucony o 13:53 z powodu pełnej kolejki.
# Pacjent 86 (Priorytet 1) skończył wizytę o 13:53.
# Pacjent 98 (Priorytet 2) zaczyna wizytę o 13:53. Czas oczekiwania: 2.70 minut.
# Pacjent 91 (Priorytet 1) skończył wizytę o 13:55.
# Pacjent 44 (Priorytet 3) zaczyna wizytę o 13:55. Czas oczekiwania: 181.49 minut.
# Pacjent 102 (Priorytet 2) przyszedł do przychodni o 14:00 (priorytet: 2).
# Pacjent 98 (Priorytet 2) skończył wizytę o 14:00.
# Pacjent 102 (Priorytet 2) zaczyna wizytę o 14:00. Czas oczekiwania: 0.05 minut.
# Pacjent 103 (Priorytet 3) przyszedł do przychodni o 14:03 (priorytet: 3).
# Pacjent 104 (Priorytet 3) przyszedł do przychodni o 14:04 (priorytet: 3).
# Pacjent 105 (Priorytet 3) został odrzucony o 14:06 z powodu pełnej kolejki.
# Pacjent 106 (Priorytet 3) został odrzucony o 14:13 z powodu pełnej kolejki.
# Pacjent 107 (Priorytet 3) został odrzucony o 14:18 z powodu pełnej kolejki.
# Pacjent 44 (Priorytet 3) skończył wizytę o 14:21.
# Pacjent 52 (Priorytet 3) zaczyna wizytę o 14:21. Czas oczekiwania: 172.53 minut.
# Pacjent 52 (Priorytet 3) skończył wizytę o 14:22.
# Pacjent 56 (Priorytet 3) zaczyna wizytę o 14:22. Czas oczekiwania: 161.42 minut.
# Pacjent 108 (Priorytet 1) przyszedł do przychodni o 14:23 (priorytet: 1).
# Pacjent 109 (Priorytet 1) przyszedł do przychodni o 14:25 (priorytet: 1).
# Pacjent 102 (Priorytet 2) skończył wizytę o 14:26.
# Pacjent 108 (Priorytet 1) zaczyna wizytę o 14:26. Czas oczekiwania: 2.28 minut.
# Pacjent 108 (Priorytet 1) skończył wizytę o 14:30.
# Pacjent 109 (Priorytet 1) zaczyna wizytę o 14:30. Czas oczekiwania: 5.56 minut.
# Pacjent 110 (Priorytet 2) przyszedł do przychodni o 14:31 (priorytet: 2).
# Pacjent 85 (Priorytet 2) skończył wizytę o 14:31.
# Pacjent 110 (Priorytet 2) zaczyna wizytę o 14:31. Czas oczekiwania: 0.10 minut.
# Pacjent 111 (Priorytet 1) przyszedł do przychodni o 14:32 (priorytet: 1).
# Pacjent 112 (Priorytet 2) przyszedł do przychodni o 14:33 (priorytet: 2).
# Pacjent 109 (Priorytet 1) skończył wizytę o 14:34.
# Pacjent 111 (Priorytet 1) zaczyna wizytę o 14:34. Czas oczekiwania: 2.86 minut.
# Pacjent 113 (Priorytet 2) przyszedł do przychodni o 14:35 (priorytet: 2).
# Pacjent 114 (Priorytet 2) został odrzucony o 14:37 z powodu pełnej kolejki.
# Pacjent 110 (Priorytet 2) skończył wizytę o 14:37.
# Pacjent 112 (Priorytet 2) zaczyna wizytę o 14:37. Czas oczekiwania: 3.90 minut.
# Pacjent 115 (Priorytet 2) przyszedł do przychodni o 14:41 (priorytet: 2).
# Pacjent 116 (Priorytet 2) został odrzucony o 14:44 z powodu pełnej kolejki.
# Pacjent 111 (Priorytet 1) skończył wizytę o 14:45.
# Pacjent 113 (Priorytet 2) zaczyna wizytę o 14:45. Czas oczekiwania: 10.13 minut.
# Pacjent 117 (Priorytet 1) przyszedł do przychodni o 14:49 (priorytet: 1).
# Pacjent 112 (Priorytet 2) skończył wizytę o 14:50.
# Pacjent 117 (Priorytet 1) zaczyna wizytę o 14:50. Czas oczekiwania: 1.08 minut.
# Pacjent 118 (Priorytet 3) przyszedł do przychodni o 14:51 (priorytet: 3).
# Pacjent 113 (Priorytet 2) skończył wizytę o 14:53.
# Pacjent 115 (Priorytet 2) zaczyna wizytę o 14:53. Czas oczekiwania: 12.29 minut.
# Pacjent 119 (Priorytet 3) przyszedł do przychodni o 14:55 (priorytet: 3).
# Pacjent 117 (Priorytet 1) skończył wizytę o 14:56.
# Pacjent 57 (Priorytet 3) zaczyna wizytę o 14:56. Czas oczekiwania: 193.61 minut.
# Pacjent 56 (Priorytet 3) skończył wizytę o 14:59.
# Pacjent 68 (Priorytet 3) zaczyna wizytę o 14:59. Czas oczekiwania: 160.50 minut.
# Pacjent 115 (Priorytet 2) skończył wizytę o 15:00.
# Pacjent 81 (Priorytet 3) zaczyna wizytę o 15:00. Czas oczekiwania: 128.63 minut.
# Pacjent 81 (Priorytet 3) skończył wizytę o 15:00.
# Pacjent 84 (Priorytet 3) zaczyna wizytę o 15:00. Czas oczekiwania: 110.63 minut.
# Pacjent 57 (Priorytet 3) skończył wizytę o 15:02.
# Pacjent 88 (Priorytet 3) zaczyna wizytę o 15:02. Czas oczekiwania: 92.73 minut.
# Pacjent 68 (Priorytet 3) skończył wizytę o 15:03.
# Pacjent 92 (Priorytet 3) zaczyna wizytę o 15:03. Czas oczekiwania: 82.03 minut.
# Pacjent 84 (Priorytet 3) skończył wizytę o 15:05.
# Pacjent 103 (Priorytet 3) zaczyna wizytę o 15:05. Czas oczekiwania: 61.88 minut.
# Pacjent 120 (Priorytet 3) przyszedł do przychodni o 15:06 (priorytet: 3).
# Pacjent 103 (Priorytet 3) skończył wizytę o 15:07.
# Pacjent 104 (Priorytet 3) zaczyna wizytę o 15:07. Czas oczekiwania: 62.41 minut.
# Pacjent 121 (Priorytet 1) przyszedł do przychodni o 15:08 (priorytet: 1).
# Pacjent 92 (Priorytet 3) skończył wizytę o 15:09.
# Pacjent 121 (Priorytet 1) zaczyna wizytę o 15:09. Czas oczekiwania: 1.64 minut.
# Pacjent 121 (Priorytet 1) skończył wizytę o 15:12.
# Pacjent 118 (Priorytet 3) zaczyna wizytę o 15:12. Czas oczekiwania: 21.46 minut.
# Pacjent 118 (Priorytet 3) skończył wizytę o 15:13.
# Pacjent 119 (Priorytet 3) zaczyna wizytę o 15:13. Czas oczekiwania: 18.45 minut.
# Pacjent 88 (Priorytet 3) skończył wizytę o 15:16.
# Pacjent 120 (Priorytet 3) zaczyna wizytę o 15:16. Czas oczekiwania: 10.20 minut.
# Pacjent 122 (Priorytet 2) przyszedł do przychodni o 15:21 (priorytet: 2).
# Pacjent 119 (Priorytet 3) skończył wizytę o 15:25.
# Pacjent 122 (Priorytet 2) zaczyna wizytę o 15:25. Czas oczekiwania: 3.97 minut.
# Pacjent 120 (Priorytet 3) skończył wizytę o 15:27.
# Pacjent 122 (Priorytet 2) skończył wizytę o 15:28.
# Pacjent 123 (Priorytet 3) przyszedł do przychodni o 15:28 (priorytet: 3).
# Pacjent 123 (Priorytet 3) zaczyna wizytę o 15:28. Czas oczekiwania: 0.00 minut.
# Pacjent 124 (Priorytet 3) przyszedł do przychodni o 15:29 (priorytet: 3).
# Pacjent 124 (Priorytet 3) zaczyna wizytę o 15:29. Czas oczekiwania: 0.00 minut.
# Pacjent 104 (Priorytet 3) skończył wizytę o 15:29.
# Pacjent 125 (Priorytet 3) przyszedł do przychodni o 15:30 (priorytet: 3).
# Pacjent 125 (Priorytet 3) zaczyna wizytę o 15:30. Czas oczekiwania: 0.00 minut.
# Pacjent 125 (Priorytet 3) skończył wizytę o 15:32.
# Pacjent 126 (Priorytet 2) przyszedł do przychodni o 15:34 (priorytet: 2).
# Pacjent 126 (Priorytet 2) zaczyna wizytę o 15:34. Czas oczekiwania: 0.00 minut.
# Pacjent 126 (Priorytet 2) skończył wizytę o 15:35.
# Pacjent 123 (Priorytet 3) skończył wizytę o 15:35.
# Pacjent 127 (Priorytet 1) przyszedł do przychodni o 15:36 (priorytet: 1).
# Pacjent 127 (Priorytet 1) zaczyna wizytę o 15:36. Czas oczekiwania: 0.00 minut.
# Pacjent 128 (Priorytet 1) przyszedł do przychodni o 15:40 (priorytet: 1).
# Pacjent 128 (Priorytet 1) zaczyna wizytę o 15:40. Czas oczekiwania: 0.00 minut.
# Pacjent 127 (Priorytet 1) skończył wizytę o 15:41.
# Pacjent 124 (Priorytet 3) skończył wizytę o 15:41.
# Pacjent 129 (Priorytet 3) przyszedł do przychodni o 15:44 (priorytet: 3).
# Pacjent 129 (Priorytet 3) zaczyna wizytę o 15:44. Czas oczekiwania: 0.00 minut.
# Pacjent 128 (Priorytet 1) skończył wizytę o 15:44.
# Pacjent 130 (Priorytet 2) przyszedł do przychodni o 15:46 (priorytet: 2).
# Pacjent 130 (Priorytet 2) zaczyna wizytę o 15:46. Czas oczekiwania: 0.00 minut.
# Pacjent 131 (Priorytet 1) przyszedł do przychodni o 15:48 (priorytet: 1).
# Pacjent 131 (Priorytet 1) zaczyna wizytę o 15:48. Czas oczekiwania: 0.00 minut.
# Pacjent 132 (Priorytet 3) przyszedł do przychodni o 15:50 (priorytet: 3).
# Pacjent 133 (Priorytet 2) przyszedł do przychodni o 15:52 (priorytet: 2).
# Pacjent 134 (Priorytet 3) przyszedł do przychodni o 15:53 (priorytet: 3).
# Pacjent 135 (Priorytet 1) przyszedł do przychodni o 15:55 (priorytet: 1).
# Pacjent 131 (Priorytet 1) skończył wizytę o 15:56.
# Pacjent 135 (Priorytet 1) zaczyna wizytę o 15:56. Czas oczekiwania: 0.45 minut.
# Pacjent 129 (Priorytet 3) skończył wizytę o 15:57.
# Pacjent 133 (Priorytet 2) zaczyna wizytę o 15:57. Czas oczekiwania: 5.61 minut.
#
# Symulacja zakończona.
# Liczba obsłużonych pacjentów: 93
# Liczba odrzuconych pacjentów: 37
# Średni czas oczekiwania: 34.78 minut
