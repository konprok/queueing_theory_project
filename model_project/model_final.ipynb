# %% [markdown]
# # Symulacja pracy przychodni

# %%
import simpy
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Parametry symulacji

# %%
LAMBDA = 15  # średnia liczba pacjentów na godzinę
CZAS_SYMULACJI = 8 * 60  # symulacja 8 godzin (w minutach)
LEKARZE = 3  # liczba lekarzy
WIELKOSC_KOLEJKI = 10  # maksymalna pojemność kolejki

# Ustawienia czasów wizyt dla poszczególnych lekarzy (w minutach)
CZASY_WIZYT_LEKARZY = [10, 15, 20]
PRIORYTETY = [1, 2, 3] # 1 - najwyższy, 3 - najniższy
ROZKLAD_PRIORYTETÓW = [0.1, 0.2, 0.7] # 1- 10%, 2- 20%, 3- 70%

# %%
# Zmienne pomocnicze
waiting_times_priority_1 = []
waiting_times_priority_2 = []
waiting_times_priority_3 = []

total_patients = 0
waiting_times = []
rejected_patients = 0

time_data = []
queue_data_priority_1 = []
queue_data_priority_2 = []
queue_data_priority_3 = []
total_queue_data = []
in_service_data = []
rejected_data = []

# %%
def format_time(minuty):
    godzina = int(minuty // 60 + 8)
    minuta = int(minuty % 60)
    return f"{godzina:02}:{minuta:02}"

class Przychodnia:
    def __init__(self, env, liczba_lekarzy, czasy_wizyt):
        self.env = env
        self.lekarz = simpy.PriorityResource(env, capacity=liczba_lekarzy)
        self.patients_in_queue = {1: 0, 2: 0, 3: 0}
        self.patients_in_service = 0
        self.czasy_wizyt = czasy_wizyt

    def wizyta(self, pacjent, lekarz_index):
        """Symulacja wizyty pacjenta z różnym czasem trwania dla każdego lekarza"""
        self.patients_in_service += 1
        update_data(self.env.now, self.patients_in_queue, self.patients_in_service) 

        czas_wizyty = self.czasy_wizyt[lekarz_index]
        yield self.env.timeout(czas_wizyty)

        self.patients_in_service -= 1
        update_data(self.env.now, self.patients_in_queue, self.patients_in_service)
        print(f"{pacjent['name']} skończył wizytę o {format_time(self.env.now)}.")

def pacjent(env, name, przychodnia, priorytet):
    global total_patients, rejected_patients
    arrival_time = env.now

    if sum(przychodnia.patients_in_queue.values()) >= WIELKOSC_KOLEJKI:
        if priorytet < 3 and przychodnia.patients_in_queue[3] > 0:
            if przychodnia.patients_in_queue[3] > 0:
                przychodnia.patients_in_queue[3] -= 1
                print(f"Pacjent o priorytecie 3 został usunięty z kolejki, aby zrobić miejsce dla {name} (Priorytet {priorytet}).")
        elif priorytet < 2 and przychodnia.patients_in_queue[2] > 0:
            if przychodnia.patients_in_queue[2] > 0:
                przychodnia.patients_in_queue[2] -= 1
                print(f"Pacjent o priorytecie 2 został usunięty z kolejki, aby zrobić miejsce dla {name} (Priorytet {priorytet}).")
        else:
            queue_status = f"Priorytet 1: {przychodnia.patients_in_queue[1]}, Priorytet 2: {przychodnia.patients_in_queue[2]}, Priorytet 3: {przychodnia.patients_in_queue[3]}"
            print(f"{name} (Priorytet {priorytet}) został odrzucony o {format_time(arrival_time)} z powodu pełnej kolejki. Stan kolejki: {queue_status}.")
            rejected_patients += 1
            rejected_data.append((env.now, rejected_patients))
            return

    print(f"{name} przyszedł do przychodni o {format_time(arrival_time)} (priorytet: {priorytet}).")
    przychodnia.patients_in_queue[priorytet] += 1
    update_data(env.now, przychodnia.patients_in_queue, przychodnia.patients_in_service)

    with przychodnia.lekarz.request(priority=priorytet) as request:
        yield request
        przychodnia.patients_in_queue[priorytet] -= 1
        waiting_time = env.now - arrival_time
        waiting_times.append(waiting_time)

        if priorytet == 1:
            waiting_times_priority_1.append(waiting_time)
        elif priorytet == 2:
            waiting_times_priority_2.append(waiting_time)
        else:
            waiting_times_priority_3.append(waiting_time)

        lekarz_index = random.randint(0, len(przychodnia.czasy_wizyt) - 1)
        print(f"{name} zaczyna wizytę u lekarza {lekarz_index + 1} o {format_time(env.now)}. Czas oczekiwania: {waiting_time:.2f} minut.")

        yield env.process(przychodnia.wizyta({'name': name}, lekarz_index))
        total_patients += 1


def proces_nadejscia(env, przychodnia):
    """Generowanie pacjentów zgodnie z procesem Poissona"""
    i = 0
    while True:
        czas_nastepnego = random.expovariate(LAMBDA / 60)
        yield env.timeout(czas_nastepnego)
        i += 1

        priorytet = random.choices(PRIORYTETY, weights=ROZKLAD_PRIORYTETÓW)[0]
        name = f"Pacjent {i} (Priorytet {priorytet})"

        env.process(pacjent(env, name, przychodnia, priorytet))

def update_data(time, patients_in_queue, patients_in_service):
    """Funkcja do aktualizacji danych do wykresów"""
    time_data.append(time)
    queue_data_priority_1.append(patients_in_queue[1])
    queue_data_priority_2.append(patients_in_queue[2])
    queue_data_priority_3.append(patients_in_queue[3])
    total_queue_data.append(sum(patients_in_queue.values()))
    in_service_data.append(patients_in_service)

def run_simulation():
    global total_patients, waiting_times, rejected_patients
    env = simpy.Environment()
    przychodnia = Przychodnia(env, LEKARZE, CZASY_WIZYT_LEKARZY)

    env.process(proces_nadejscia(env, przychodnia))

    env.run(until=CZAS_SYMULACJI)

    print("\nSymulacja zakończona.")
    print(f"Liczba obsłużonych pacjentów: {total_patients}")
    print(f"Liczba odrzuconych pacjentów: {rejected_patients}")
    if waiting_times:
        print(f"Średni czas oczekiwania: {np.mean(waiting_times):.2f} minut")
    else:
        print("Nie było żadnych pacjentów w kolejce.")

if __name__ == "__main__":
    run_simulation()

    # Wykres 1: Całkowita liczba pacjentów w kolejce i liczba pacjentów obsługiwanych
    plt.figure(figsize=(10, 5))
    plt.step(time_data, total_queue_data, label='Całkowita liczba pacjentów w kolejce', color='blue', where='post')
    plt.step(time_data, in_service_data, label='Liczba pacjentów obsługiwanych', color='green', where='post')
    plt.xlabel("Czas [minuty]")
    plt.ylabel("Liczba pacjentów")
    plt.title("Całkowita długość kolejki i liczba pacjentów obsługiwanych w czasie")
    plt.legend()
    plt.grid()
    plt.show()

    # Wykres 2: Liczba pacjentów w kolejce dla każdego priorytetu
    plt.figure(figsize=(10, 5))
    plt.step(time_data, queue_data_priority_1, label='Priorytet 1', color='blue', where='post')
    plt.step(time_data, queue_data_priority_2, label='Priorytet 2', color='green', where='post')
    plt.step(time_data, queue_data_priority_3, label='Priorytet 3', color='red', where='post')
    plt.xlabel("Czas [minuty]")
    plt.ylabel("Liczba pacjentów")
    plt.title("Liczba pacjentów w kolejce dla każdego priorytetu w czasie")
    plt.legend()
    plt.grid()
    plt.show()


    # Wykres 3: Liczba odrzuconych pacjentów w czasie
    rejected_times, rejected_counts = zip(*rejected_data) if rejected_data else ([], [])
    plt.figure(figsize=(10, 5))
    plt.step(rejected_times, rejected_counts, label='Odrzuceni pacjenci', color='red', where='post')
    plt.xlabel("Czas [minuty]")
    plt.ylabel("Liczba odrzuconych pacjentów")
    plt.title("Liczba odrzuconych pacjentów w czasie")
    plt.legend()
    plt.grid()
    plt.show()
# Out:
# Pacjent 1 (Priorytet 3) przyszedł do przychodni o 08:07 (priorytet: 3).
# Pacjent 1 (Priorytet 3) zaczyna wizytę u lekarza 2 o 08:07. Czas oczekiwania: 0.00 minut.
# Pacjent 2 (Priorytet 3) przyszedł do przychodni o 08:08 (priorytet: 3).
# Pacjent 2 (Priorytet 3) zaczyna wizytę u lekarza 2 o 08:08. Czas oczekiwania: 0.00 minut.
# Pacjent 3 (Priorytet 2) przyszedł do przychodni o 08:12 (priorytet: 2).
# Pacjent 3 (Priorytet 2) zaczyna wizytę u lekarza 1 o 08:12. Czas oczekiwania: 0.00 minut.
# Pacjent 4 (Priorytet 2) przyszedł do przychodni o 08:16 (priorytet: 2).
# Pacjent 5 (Priorytet 1) przyszedł do przychodni o 08:17 (priorytet: 1).
# Pacjent 1 (Priorytet 3) skończył wizytę o 08:22.
# Pacjent 5 (Priorytet 1) zaczyna wizytę u lekarza 3 o 08:22. Czas oczekiwania: 4.92 minut.
# Pacjent 3 (Priorytet 2) skończył wizytę o 08:22.
# Pacjent 4 (Priorytet 2) zaczyna wizytę u lekarza 1 o 08:22. Czas oczekiwania: 6.61 minut.
# Pacjent 2 (Priorytet 3) skończył wizytę o 08:23.
# Pacjent 6 (Priorytet 1) przyszedł do przychodni o 08:24 (priorytet: 1).
# Pacjent 6 (Priorytet 1) zaczyna wizytę u lekarza 1 o 08:24. Czas oczekiwania: 0.00 minut.
# Pacjent 4 (Priorytet 2) skończył wizytę o 08:32.
# Pacjent 6 (Priorytet 1) skończył wizytę o 08:34.
# Pacjent 7 (Priorytet 3) przyszedł do przychodni o 08:38 (priorytet: 3).
# Pacjent 7 (Priorytet 3) zaczyna wizytę u lekarza 3 o 08:38. Czas oczekiwania: 0.00 minut.
# Pacjent 5 (Priorytet 1) skończył wizytę o 08:42.
# Pacjent 8 (Priorytet 3) przyszedł do przychodni o 08:44 (priorytet: 3).
# Pacjent 8 (Priorytet 3) zaczyna wizytę u lekarza 2 o 08:44. Czas oczekiwania: 0.00 minut.
# Pacjent 9 (Priorytet 2) przyszedł do przychodni o 08:47 (priorytet: 2).
# Pacjent 9 (Priorytet 2) zaczyna wizytę u lekarza 2 o 08:47. Czas oczekiwania: 0.00 minut.
# Pacjent 10 (Priorytet 3) przyszedł do przychodni o 08:50 (priorytet: 3).
# Pacjent 11 (Priorytet 3) przyszedł do przychodni o 08:54 (priorytet: 3).
# Pacjent 7 (Priorytet 3) skończył wizytę o 08:58.
# Pacjent 10 (Priorytet 3) zaczyna wizytę u lekarza 2 o 08:58. Czas oczekiwania: 8.14 minut.
# Pacjent 12 (Priorytet 3) przyszedł do przychodni o 08:59 (priorytet: 3).
# Pacjent 8 (Priorytet 3) skończył wizytę o 08:59.
# Pacjent 11 (Priorytet 3) zaczyna wizytę u lekarza 3 o 08:59. Czas oczekiwania: 4.47 minut.
# Pacjent 13 (Priorytet 3) przyszedł do przychodni o 09:01 (priorytet: 3).
# Pacjent 9 (Priorytet 2) skończył wizytę o 09:02.
# Pacjent 12 (Priorytet 3) zaczyna wizytę u lekarza 3 o 09:02. Czas oczekiwania: 3.56 minut.
# Pacjent 14 (Priorytet 2) przyszedł do przychodni o 09:07 (priorytet: 2).
# Pacjent 15 (Priorytet 3) przyszedł do przychodni o 09:09 (priorytet: 3).
# Pacjent 10 (Priorytet 3) skończył wizytę o 09:13.
# Pacjent 14 (Priorytet 2) zaczyna wizytę u lekarza 2 o 09:13. Czas oczekiwania: 6.11 minut.
# Pacjent 16 (Priorytet 3) przyszedł do przychodni o 09:15 (priorytet: 3).
# Pacjent 11 (Priorytet 3) skończył wizytę o 09:19.
# Pacjent 13 (Priorytet 3) zaczyna wizytę u lekarza 3 o 09:19. Czas oczekiwania: 18.08 minut.
# Pacjent 17 (Priorytet 3) przyszedł do przychodni o 09:19 (priorytet: 3).
# Pacjent 18 (Priorytet 3) przyszedł do przychodni o 09:20 (priorytet: 3).
# Pacjent 19 (Priorytet 2) przyszedł do przychodni o 09:22 (priorytet: 2).
# Pacjent 12 (Priorytet 3) skończył wizytę o 09:22.
# Pacjent 19 (Priorytet 2) zaczyna wizytę u lekarza 2 o 09:22. Czas oczekiwania: 0.21 minut.
# Pacjent 20 (Priorytet 3) przyszedł do przychodni o 09:28 (priorytet: 3).
# Pacjent 14 (Priorytet 2) skończył wizytę o 09:28.
# Pacjent 15 (Priorytet 3) zaczyna wizytę u lekarza 2 o 09:28. Czas oczekiwania: 19.54 minut.
# Pacjent 21 (Priorytet 1) przyszedł do przychodni o 09:32 (priorytet: 1).
# Pacjent 22 (Priorytet 2) przyszedł do przychodni o 09:36 (priorytet: 2).
# Pacjent 23 (Priorytet 2) przyszedł do przychodni o 09:37 (priorytet: 2).
# Pacjent 19 (Priorytet 2) skończył wizytę o 09:37.
# Pacjent 21 (Priorytet 1) zaczyna wizytę u lekarza 3 o 09:37. Czas oczekiwania: 5.04 minut.
# Pacjent 13 (Priorytet 3) skończył wizytę o 09:39.
# Pacjent 22 (Priorytet 2) zaczyna wizytę u lekarza 1 o 09:39. Czas oczekiwania: 2.83 minut.
# Pacjent 24 (Priorytet 3) przyszedł do przychodni o 09:43 (priorytet: 3).
# Pacjent 15 (Priorytet 3) skończył wizytę o 09:43.
# Pacjent 23 (Priorytet 2) zaczyna wizytę u lekarza 2 o 09:43. Czas oczekiwania: 6.21 minut.
# Pacjent 25 (Priorytet 1) przyszedł do przychodni o 09:43 (priorytet: 1).
# Pacjent 26 (Priorytet 3) przyszedł do przychodni o 09:45 (priorytet: 3).
# Pacjent 27 (Priorytet 2) przyszedł do przychodni o 09:47 (priorytet: 2).
# Pacjent 22 (Priorytet 2) skończył wizytę o 09:49.
# Pacjent 25 (Priorytet 1) zaczyna wizytę u lekarza 1 o 09:49. Czas oczekiwania: 5.64 minut.
# Pacjent 28 (Priorytet 3) przyszedł do przychodni o 09:50 (priorytet: 3).
# Pacjent 29 (Priorytet 2) przyszedł do przychodni o 09:55 (priorytet: 2).
# Pacjent 21 (Priorytet 1) skończył wizytę o 09:57.
# Pacjent 27 (Priorytet 2) zaczyna wizytę u lekarza 1 o 09:57. Czas oczekiwania: 10.19 minut.
# Pacjent 23 (Priorytet 2) skończył wizytę o 09:58.
# Pacjent 29 (Priorytet 2) zaczyna wizytę u lekarza 3 o 09:58. Czas oczekiwania: 2.84 minut.
# Pacjent 30 (Priorytet 3) przyszedł do przychodni o 09:59 (priorytet: 3).
# Pacjent 25 (Priorytet 1) skończył wizytę o 09:59.
# Pacjent 16 (Priorytet 3) zaczyna wizytę u lekarza 2 o 09:59. Czas oczekiwania: 44.18 minut.
# Pacjent 31 (Priorytet 3) przyszedł do przychodni o 09:59 (priorytet: 3).
# Pacjent 32 (Priorytet 3) przyszedł do przychodni o 10:06 (priorytet: 3).
# Pacjent 27 (Priorytet 2) skończył wizytę o 10:07.
# Pacjent 17 (Priorytet 3) zaczyna wizytę u lekarza 1 o 10:07. Czas oczekiwania: 48.30 minut.
# Pacjent 33 (Priorytet 3) przyszedł do przychodni o 10:13 (priorytet: 3).
# Pacjent 34 (Priorytet 2) przyszedł do przychodni o 10:14 (priorytet: 2).
# Pacjent 16 (Priorytet 3) skończył wizytę o 10:14.
# Pacjent 34 (Priorytet 2) zaczyna wizytę u lekarza 2 o 10:14. Czas oczekiwania: 0.29 minut.
# Pacjent 35 (Priorytet 3) przyszedł do przychodni o 10:17 (priorytet: 3).
# Pacjent 17 (Priorytet 3) skończył wizytę o 10:17.
# Pacjent 18 (Priorytet 3) zaczyna wizytę u lekarza 1 o 10:17. Czas oczekiwania: 57.60 minut.
# Pacjent 29 (Priorytet 2) skończył wizytę o 10:18.
# Pacjent 20 (Priorytet 3) zaczyna wizytę u lekarza 2 o 10:18. Czas oczekiwania: 50.37 minut.
# Pacjent 36 (Priorytet 3) przyszedł do przychodni o 10:19 (priorytet: 3).
# Pacjent 37 (Priorytet 2) przyszedł do przychodni o 10:23 (priorytet: 2).
# Pacjent o priorytecie 3 został usunięty z kolejki, aby zrobić miejsce dla Pacjent 38 (Priorytet 2) (Priorytet 2).
# Pacjent 38 (Priorytet 2) przyszedł do przychodni o 10:25 (priorytet: 2).
# Pacjent 18 (Priorytet 3) skończył wizytę o 10:27.
# Pacjent 37 (Priorytet 2) zaczyna wizytę u lekarza 3 o 10:27. Czas oczekiwania: 4.70 minut.
# Pacjent 34 (Priorytet 2) skończył wizytę o 10:29.
# Pacjent 38 (Priorytet 2) zaczyna wizytę u lekarza 3 o 10:29. Czas oczekiwania: 4.21 minut.
# Pacjent 39 (Priorytet 3) przyszedł do przychodni o 10:31 (priorytet: 3).
# Pacjent 20 (Priorytet 3) skończył wizytę o 10:33.
# Pacjent 24 (Priorytet 3) zaczyna wizytę u lekarza 1 o 10:33. Czas oczekiwania: 50.42 minut.
# Pacjent 40 (Priorytet 3) przyszedł do przychodni o 10:39 (priorytet: 3).
# Pacjent 24 (Priorytet 3) skończył wizytę o 10:43.
# Pacjent 26 (Priorytet 3) zaczyna wizytę u lekarza 2 o 10:43. Czas oczekiwania: 57.55 minut.
# Pacjent 41 (Priorytet 1) przyszedł do przychodni o 10:45 (priorytet: 1).
# Pacjent 37 (Priorytet 2) skończył wizytę o 10:47.
# Pacjent 41 (Priorytet 1) zaczyna wizytę u lekarza 1 o 10:47. Czas oczekiwania: 2.21 minut.
# Pacjent 38 (Priorytet 2) skończył wizytę o 10:49.
# Pacjent 28 (Priorytet 3) zaczyna wizytę u lekarza 1 o 10:49. Czas oczekiwania: 58.73 minut.
# Pacjent 42 (Priorytet 3) przyszedł do przychodni o 10:53 (priorytet: 3).
# Pacjent 43 (Priorytet 3) przyszedł do przychodni o 10:57 (priorytet: 3).
# Pacjent 44 (Priorytet 3) przyszedł do przychodni o 10:57 (priorytet: 3).
# Pacjent 41 (Priorytet 1) skończył wizytę o 10:57.
# Pacjent 30 (Priorytet 3) zaczyna wizytę u lekarza 1 o 10:57. Czas oczekiwania: 58.79 minut.
# Pacjent 26 (Priorytet 3) skończył wizytę o 10:58.
# Pacjent 31 (Priorytet 3) zaczyna wizytę u lekarza 3 o 10:58. Czas oczekiwania: 58.98 minut.
# Pacjent 28 (Priorytet 3) skończył wizytę o 10:59.
# Pacjent 32 (Priorytet 3) zaczyna wizytę u lekarza 3 o 10:59. Czas oczekiwania: 52.73 minut.
# Pacjent 45 (Priorytet 1) przyszedł do przychodni o 11:00 (priorytet: 1).
# Pacjent 46 (Priorytet 3) przyszedł do przychodni o 11:04 (priorytet: 3).
# Pacjent 30 (Priorytet 3) skończył wizytę o 11:07.
# Pacjent 45 (Priorytet 1) zaczyna wizytę u lekarza 2 o 11:07. Czas oczekiwania: 7.79 minut.
# Pacjent 47 (Priorytet 1) przyszedł do przychodni o 11:11 (priorytet: 1).
# Pacjent 48 (Priorytet 3) przyszedł do przychodni o 11:15 (priorytet: 3).
# Pacjent 31 (Priorytet 3) skończył wizytę o 11:18.
# Pacjent 47 (Priorytet 1) zaczyna wizytę u lekarza 2 o 11:18. Czas oczekiwania: 6.59 minut.
# Pacjent 32 (Priorytet 3) skończył wizytę o 11:19.
# Pacjent 33 (Priorytet 3) zaczyna wizytę u lekarza 3 o 11:19. Czas oczekiwania: 66.00 minut.
# Pacjent 49 (Priorytet 3) przyszedł do przychodni o 11:21 (priorytet: 3).
# Pacjent 45 (Priorytet 1) skończył wizytę o 11:22.
# Pacjent 35 (Priorytet 3) zaczyna wizytę u lekarza 2 o 11:22. Czas oczekiwania: 65.56 minut.
# Pacjent 47 (Priorytet 1) skończył wizytę o 11:33.
# Pacjent 36 (Priorytet 3) zaczyna wizytę u lekarza 2 o 11:33. Czas oczekiwania: 74.35 minut.
# Pacjent 50 (Priorytet 3) przyszedł do przychodni o 11:34 (priorytet: 3).
# Pacjent 51 (Priorytet 3) przyszedł do przychodni o 11:36 (priorytet: 3).
# Pacjent 35 (Priorytet 3) skończył wizytę o 11:37.
# Pacjent 39 (Priorytet 3) zaczyna wizytę u lekarza 1 o 11:37. Czas oczekiwania: 66.26 minut.
# Pacjent 33 (Priorytet 3) skończył wizytę o 11:39.
# Pacjent 40 (Priorytet 3) zaczyna wizytę u lekarza 3 o 11:39. Czas oczekiwania: 59.95 minut.
# Pacjent 52 (Priorytet 3) przyszedł do przychodni o 11:47 (priorytet: 3).
# Pacjent 39 (Priorytet 3) skończył wizytę o 11:47.
# Pacjent 42 (Priorytet 3) zaczyna wizytę u lekarza 3 o 11:47. Czas oczekiwania: 54.07 minut.
# Pacjent 36 (Priorytet 3) skończył wizytę o 11:48.
# Pacjent 43 (Priorytet 3) zaczyna wizytę u lekarza 2 o 11:48. Czas oczekiwania: 51.19 minut.
# Pacjent 53 (Priorytet 2) przyszedł do przychodni o 11:49 (priorytet: 2).
# Pacjent 54 (Priorytet 2) przyszedł do przychodni o 11:57 (priorytet: 2).
# Pacjent 55 (Priorytet 3) przyszedł do przychodni o 11:59 (priorytet: 3).
# Pacjent 40 (Priorytet 3) skończył wizytę o 11:59.
# Pacjent 53 (Priorytet 2) zaczyna wizytę u lekarza 2 o 11:59. Czas oczekiwania: 9.76 minut.
# Pacjent 56 (Priorytet 3) przyszedł do przychodni o 12:03 (priorytet: 3).
# Pacjent 43 (Priorytet 3) skończył wizytę o 12:03.
# Pacjent 54 (Priorytet 2) zaczyna wizytę u lekarza 2 o 12:03. Czas oczekiwania: 5.91 minut.
# Pacjent 57 (Priorytet 3) przyszedł do przychodni o 12:05 (priorytet: 3).
# Pacjent 42 (Priorytet 3) skończył wizytę o 12:07.
# Pacjent 44 (Priorytet 3) zaczyna wizytę u lekarza 3 o 12:07. Czas oczekiwania: 70.31 minut.
# Pacjent 53 (Priorytet 2) skończył wizytę o 12:14.
# Pacjent 46 (Priorytet 3) zaczyna wizytę u lekarza 2 o 12:14. Czas oczekiwania: 69.62 minut.
# Pacjent 58 (Priorytet 3) przyszedł do przychodni o 12:18 (priorytet: 3).
# Pacjent 54 (Priorytet 2) skończył wizytę o 12:18.
# Pacjent 48 (Priorytet 3) zaczyna wizytę u lekarza 1 o 12:18. Czas oczekiwania: 63.07 minut.
# Pacjent 59 (Priorytet 3) przyszedł do przychodni o 12:18 (priorytet: 3).
# Pacjent 60 (Priorytet 3) przyszedł do przychodni o 12:20 (priorytet: 3).
# Pacjent 61 (Priorytet 2) przyszedł do przychodni o 12:23 (priorytet: 2).
# Pacjent 44 (Priorytet 3) skończył wizytę o 12:27.
# Pacjent 61 (Priorytet 2) zaczyna wizytę u lekarza 3 o 12:27. Czas oczekiwania: 4.17 minut.
# Pacjent 48 (Priorytet 3) skończył wizytę o 12:28.
# Pacjent 49 (Priorytet 3) zaczyna wizytę u lekarza 3 o 12:28. Czas oczekiwania: 67.43 minut.
# Pacjent 46 (Priorytet 3) skończył wizytę o 12:29.
# Pacjent 50 (Priorytet 3) zaczyna wizytę u lekarza 2 o 12:29. Czas oczekiwania: 55.04 minut.
# Pacjent 62 (Priorytet 3) przyszedł do przychodni o 12:31 (priorytet: 3).
# Pacjent 63 (Priorytet 3) przyszedł do przychodni o 12:32 (priorytet: 3).
# Pacjent 64 (Priorytet 3) przyszedł do przychodni o 12:35 (priorytet: 3).
# Pacjent 50 (Priorytet 3) skończył wizytę o 12:44.
# Pacjent 51 (Priorytet 3) zaczyna wizytę u lekarza 3 o 12:44. Czas oczekiwania: 67.98 minut.
# Pacjent 65 (Priorytet 3) przyszedł do przychodni o 12:44 (priorytet: 3).
# Pacjent 61 (Priorytet 2) skończył wizytę o 12:47.
# Pacjent 52 (Priorytet 3) zaczyna wizytę u lekarza 3 o 12:47. Czas oczekiwania: 60.28 minut.
# Pacjent 49 (Priorytet 3) skończył wizytę o 12:48.
# Pacjent 55 (Priorytet 3) zaczyna wizytę u lekarza 1 o 12:48. Czas oczekiwania: 49.28 minut.
# Pacjent 66 (Priorytet 2) przyszedł do przychodni o 12:51 (priorytet: 2).
# Pacjent 67 (Priorytet 3) przyszedł do przychodni o 12:53 (priorytet: 3).
# Pacjent o priorytecie 3 został usunięty z kolejki, aby zrobić miejsce dla Pacjent 68 (Priorytet 1) (Priorytet 1).
# Pacjent 68 (Priorytet 1) przyszedł do przychodni o 12:53 (priorytet: 1).
# Pacjent 55 (Priorytet 3) skończył wizytę o 12:58.
# Pacjent 68 (Priorytet 1) zaczyna wizytę u lekarza 1 o 12:58. Czas oczekiwania: 5.24 minut.
# Pacjent 51 (Priorytet 3) skończył wizytę o 13:04.
# Pacjent 66 (Priorytet 2) zaczyna wizytę u lekarza 1 o 13:04. Czas oczekiwania: 12.99 minut.
# Pacjent 52 (Priorytet 3) skończył wizytę o 13:07.
# Pacjent 56 (Priorytet 3) zaczyna wizytę u lekarza 1 o 13:07. Czas oczekiwania: 64.32 minut.
# Pacjent 68 (Priorytet 1) skończył wizytę o 13:08.
# Pacjent 57 (Priorytet 3) zaczyna wizytę u lekarza 1 o 13:08. Czas oczekiwania: 62.66 minut.
# Pacjent 69 (Priorytet 3) przyszedł do przychodni o 13:10 (priorytet: 3).
# Pacjent 70 (Priorytet 3) przyszedł do przychodni o 13:11 (priorytet: 3).
# Pacjent 71 (Priorytet 3) przyszedł do przychodni o 13:12 (priorytet: 3).
# Pacjent 72 (Priorytet 1) przyszedł do przychodni o 13:14 (priorytet: 1).
# Pacjent 66 (Priorytet 2) skończył wizytę o 13:14.
# Pacjent 72 (Priorytet 1) zaczyna wizytę u lekarza 2 o 13:14. Czas oczekiwania: 0.39 minut.
# Pacjent 73 (Priorytet 3) przyszedł do przychodni o 13:15 (priorytet: 3).
# Pacjent 56 (Priorytet 3) skończył wizytę o 13:17.
# Pacjent 58 (Priorytet 3) zaczyna wizytę u lekarza 2 o 13:17. Czas oczekiwania: 59.58 minut.
# Pacjent 57 (Priorytet 3) skończył wizytę o 13:18.
# Pacjent 59 (Priorytet 3) zaczyna wizytę u lekarza 3 o 13:18. Czas oczekiwania: 59.76 minut.
# Pacjent 74 (Priorytet 3) przyszedł do przychodni o 13:19 (priorytet: 3).
# Pacjent 75 (Priorytet 2) przyszedł do przychodni o 13:22 (priorytet: 2).
# Pacjent 72 (Priorytet 1) skończył wizytę o 13:29.
# Pacjent 75 (Priorytet 2) zaczyna wizytę u lekarza 3 o 13:29. Czas oczekiwania: 7.11 minut.
# Pacjent 76 (Priorytet 2) przyszedł do przychodni o 13:32 (priorytet: 2).
# Pacjent 58 (Priorytet 3) skończył wizytę o 13:32.
# Pacjent 76 (Priorytet 2) zaczyna wizytę u lekarza 1 o 13:32. Czas oczekiwania: 0.23 minut.
# Pacjent 77 (Priorytet 2) przyszedł do przychodni o 13:33 (priorytet: 2).
# Pacjent o priorytecie 3 został usunięty z kolejki, aby zrobić miejsce dla Pacjent 78 (Priorytet 1) (Priorytet 1).
# Pacjent 78 (Priorytet 1) przyszedł do przychodni o 13:36 (priorytet: 1).
# Pacjent 59 (Priorytet 3) skończył wizytę o 13:38.
# Pacjent 78 (Priorytet 1) zaczyna wizytę u lekarza 2 o 13:38. Czas oczekiwania: 1.71 minut.
# Pacjent 79 (Priorytet 3) przyszedł do przychodni o 13:39 (priorytet: 3).
# Pacjent 76 (Priorytet 2) skończył wizytę o 13:42.
# Pacjent 77 (Priorytet 2) zaczyna wizytę u lekarza 1 o 13:42. Czas oczekiwania: 9.81 minut.
# Pacjent 75 (Priorytet 2) skończył wizytę o 13:49.
# Pacjent 60 (Priorytet 3) zaczyna wizytę u lekarza 2 o 13:49. Czas oczekiwania: 89.17 minut.
# Pacjent 80 (Priorytet 3) przyszedł do przychodni o 13:50 (priorytet: 3).
# Pacjent 77 (Priorytet 2) skończył wizytę o 13:52.
# Pacjent 62 (Priorytet 3) zaczyna wizytę u lekarza 1 o 13:52. Czas oczekiwania: 81.07 minut.
# Pacjent 78 (Priorytet 1) skończył wizytę o 13:53.
# Pacjent 63 (Priorytet 3) zaczyna wizytę u lekarza 1 o 13:53. Czas oczekiwania: 81.38 minut.
# Pacjent 81 (Priorytet 3) przyszedł do przychodni o 13:55 (priorytet: 3).
# Pacjent 82 (Priorytet 1) przyszedł do przychodni o 14:00 (priorytet: 1).
# Pacjent 62 (Priorytet 3) skończył wizytę o 14:02.
# Pacjent 82 (Priorytet 1) zaczyna wizytę u lekarza 2 o 14:02. Czas oczekiwania: 1.99 minut.
# Pacjent 63 (Priorytet 3) skończył wizytę o 14:03.
# Pacjent 64 (Priorytet 3) zaczyna wizytę u lekarza 2 o 14:03. Czas oczekiwania: 88.17 minut.
# Pacjent 60 (Priorytet 3) skończył wizytę o 14:04.
# Pacjent 65 (Priorytet 3) zaczyna wizytę u lekarza 2 o 14:04. Czas oczekiwania: 79.53 minut.
# Pacjent 83 (Priorytet 3) przyszedł do przychodni o 14:10 (priorytet: 3).
# Pacjent 84 (Priorytet 2) przyszedł do przychodni o 14:17 (priorytet: 2).
# Pacjent 82 (Priorytet 1) skończył wizytę o 14:17.
# Pacjent 84 (Priorytet 2) zaczyna wizytę u lekarza 1 o 14:17. Czas oczekiwania: 0.69 minut.
# Pacjent 64 (Priorytet 3) skończył wizytę o 14:18.
# Pacjent 67 (Priorytet 3) zaczyna wizytę u lekarza 1 o 14:18. Czas oczekiwania: 85.25 minut.
# Pacjent 65 (Priorytet 3) skończył wizytę o 14:19.
# Pacjent 69 (Priorytet 3) zaczyna wizytę u lekarza 1 o 14:19. Czas oczekiwania: 68.83 minut.
# Pacjent 85 (Priorytet 1) przyszedł do przychodni o 14:19 (priorytet: 1).
# Pacjent 86 (Priorytet 3) przyszedł do przychodni o 14:20 (priorytet: 3).
# Pacjent 84 (Priorytet 2) skończył wizytę o 14:27.
# Pacjent 85 (Priorytet 1) zaczyna wizytę u lekarza 1 o 14:27. Czas oczekiwania: 8.12 minut.
# Pacjent 67 (Priorytet 3) skończył wizytę o 14:28.
# Pacjent 70 (Priorytet 3) zaczyna wizytę u lekarza 2 o 14:28. Czas oczekiwania: 77.42 minut.
# Pacjent 69 (Priorytet 3) skończył wizytę o 14:29.
# Pacjent 71 (Priorytet 3) zaczyna wizytę u lekarza 1 o 14:29. Czas oczekiwania: 76.67 minut.
# Pacjent 87 (Priorytet 3) przyszedł do przychodni o 14:30 (priorytet: 3).
# Pacjent 88 (Priorytet 3) przyszedł do przychodni o 14:31 (priorytet: 3).
# Pacjent 89 (Priorytet 3) przyszedł do przychodni o 14:31 (priorytet: 3).
# Pacjent 90 (Priorytet 2) przyszedł do przychodni o 14:34 (priorytet: 2).
# Pacjent 85 (Priorytet 1) skończył wizytę o 14:37.
# Pacjent 90 (Priorytet 2) zaczyna wizytę u lekarza 2 o 14:37. Czas oczekiwania: 3.40 minut.
# Pacjent 71 (Priorytet 3) skończył wizytę o 14:39.
# Pacjent 73 (Priorytet 3) zaczyna wizytę u lekarza 3 o 14:39. Czas oczekiwania: 84.24 minut.
# Pacjent 91 (Priorytet 2) przyszedł do przychodni o 14:41 (priorytet: 2).
# Pacjent 92 (Priorytet 3) przyszedł do przychodni o 14:43 (priorytet: 3).
# Pacjent 70 (Priorytet 3) skończył wizytę o 14:43.
# Pacjent 91 (Priorytet 2) zaczyna wizytę u lekarza 1 o 14:43. Czas oczekiwania: 1.78 minut.
# Pacjent 93 (Priorytet 1) przyszedł do przychodni o 14:48 (priorytet: 1).
# Pacjent 94 (Priorytet 3) przyszedł do przychodni o 14:52 (priorytet: 3).
# Pacjent 90 (Priorytet 2) skończył wizytę o 14:52.
# Pacjent 93 (Priorytet 1) zaczyna wizytę u lekarza 2 o 14:52. Czas oczekiwania: 4.16 minut.
# Pacjent 91 (Priorytet 2) skończył wizytę o 14:53.
# Pacjent 74 (Priorytet 3) zaczyna wizytę u lekarza 1 o 14:53. Czas oczekiwania: 93.73 minut.
# Pacjent 95 (Priorytet 2) przyszedł do przychodni o 14:54 (priorytet: 2).
# Pacjent 96 (Priorytet 3) przyszedł do przychodni o 14:59 (priorytet: 3).
# Pacjent 73 (Priorytet 3) skończył wizytę o 14:59.
# Pacjent 95 (Priorytet 2) zaczyna wizytę u lekarza 3 o 14:59. Czas oczekiwania: 4.75 minut.
# Pacjent 97 (Priorytet 3) przyszedł do przychodni o 14:59 (priorytet: 3).
# Pacjent 98 (Priorytet 3) przyszedł do przychodni o 15:02 (priorytet: 3).
# Pacjent 74 (Priorytet 3) skończył wizytę o 15:03.
# Pacjent 79 (Priorytet 3) zaczyna wizytę u lekarza 2 o 15:03. Czas oczekiwania: 83.72 minut.
# Pacjent 93 (Priorytet 1) skończył wizytę o 15:07.
# Pacjent 80 (Priorytet 3) zaczyna wizytę u lekarza 3 o 15:07. Czas oczekiwania: 76.92 minut.
# Pacjent 99 (Priorytet 1) przyszedł do przychodni o 15:16 (priorytet: 1).
# Pacjent 100 (Priorytet 3) przyszedł do przychodni o 15:16 (priorytet: 3).
# Pacjent 101 (Priorytet 3) (Priorytet 3) został odrzucony o 15:18 z powodu pełnej kolejki. Stan kolejki: Priorytet 1: 1, Priorytet 2: 0, Priorytet 3: 9.
# Pacjent 79 (Priorytet 3) skończył wizytę o 15:18.
# Pacjent 99 (Priorytet 1) zaczyna wizytę u lekarza 2 o 15:18. Czas oczekiwania: 2.46 minut.
# Pacjent 95 (Priorytet 2) skończył wizytę o 15:19.
# Pacjent 81 (Priorytet 3) zaczyna wizytę u lekarza 3 o 15:19. Czas oczekiwania: 83.85 minut.
# Pacjent 102 (Priorytet 2) przyszedł do przychodni o 15:19 (priorytet: 2).
# Pacjent 103 (Priorytet 3) przyszedł do przychodni o 15:26 (priorytet: 3).
# Pacjent 104 (Priorytet 3) (Priorytet 3) został odrzucony o 15:27 z powodu pełnej kolejki. Stan kolejki: Priorytet 1: 0, Priorytet 2: 1, Priorytet 3: 9.
# Pacjent 80 (Priorytet 3) skończył wizytę o 15:27.
# Pacjent 102 (Priorytet 2) zaczyna wizytę u lekarza 1 o 15:27. Czas oczekiwania: 7.91 minut.
# Pacjent 105 (Priorytet 2) przyszedł do przychodni o 15:28 (priorytet: 2).
# Pacjent 106 (Priorytet 3) (Priorytet 3) został odrzucony o 15:28 z powodu pełnej kolejki. Stan kolejki: Priorytet 1: 0, Priorytet 2: 1, Priorytet 3: 9.
# Pacjent 107 (Priorytet 3) (Priorytet 3) został odrzucony o 15:30 z powodu pełnej kolejki. Stan kolejki: Priorytet 1: 0, Priorytet 2: 1, Priorytet 3: 9.
# Pacjent 99 (Priorytet 1) skończył wizytę o 15:33.
# Pacjent 105 (Priorytet 2) zaczyna wizytę u lekarza 3 o 15:33. Czas oczekiwania: 5.53 minut.
# Pacjent 108 (Priorytet 3) przyszedł do przychodni o 15:36 (priorytet: 3).
# Pacjent 109 (Priorytet 3) (Priorytet 3) został odrzucony o 15:37 z powodu pełnej kolejki. Stan kolejki: Priorytet 1: 0, Priorytet 2: 0, Priorytet 3: 10.
# Pacjent 102 (Priorytet 2) skończył wizytę o 15:37.
# Pacjent 83 (Priorytet 3) zaczyna wizytę u lekarza 3 o 15:37. Czas oczekiwania: 86.85 minut.
# Pacjent 81 (Priorytet 3) skończył wizytę o 15:39.
# Pacjent 86 (Priorytet 3) zaczyna wizytę u lekarza 1 o 15:39. Czas oczekiwania: 78.93 minut.
# Pacjent 110 (Priorytet 3) przyszedł do przychodni o 15:43 (priorytet: 3).
# Pacjent 111 (Priorytet 1) przyszedł do przychodni o 15:47 (priorytet: 1).
# Pacjent 86 (Priorytet 3) skończył wizytę o 15:49.
# Pacjent 111 (Priorytet 1) zaczyna wizytę u lekarza 1 o 15:49. Czas oczekiwania: 1.63 minut.
# Pacjent 112 (Priorytet 3) przyszedł do przychodni o 15:49 (priorytet: 3).
# Pacjent o priorytecie 3 został usunięty z kolejki, aby zrobić miejsce dla Pacjent 113 (Priorytet 1) (Priorytet 1).
# Pacjent 113 (Priorytet 1) przyszedł do przychodni o 15:52 (priorytet: 1).
# Pacjent 105 (Priorytet 2) skończył wizytę o 15:53.
# Pacjent 113 (Priorytet 1) zaczyna wizytę u lekarza 1 o 15:53. Czas oczekiwania: 0.84 minut.
# Pacjent 114 (Priorytet 3) przyszedł do przychodni o 15:57 (priorytet: 3).
# Pacjent 83 (Priorytet 3) skończył wizytę o 15:57.
# Pacjent 87 (Priorytet 3) zaczyna wizytę u lekarza 1 o 15:57. Czas oczekiwania: 87.11 minut.
# Pacjent 111 (Priorytet 1) skończył wizytę o 15:59.
# Pacjent 88 (Priorytet 3) zaczyna wizytę u lekarza 3 o 15:59. Czas oczekiwania: 88.29 minut.
#
# Symulacja zakończona.
# Liczba obsłużonych pacjentów: 94
# Liczba odrzuconych pacjentów: 5
# Średni czas oczekiwania: 35.53 minut
